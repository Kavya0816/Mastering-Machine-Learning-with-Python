# %%
demo_list=[]

for c in 'hello':
    demo_list.append(c.upper())

# %%
demo_list
# Out:
# ['H', 'E', 'L', 'L', 'O']

# %%
c.upper() for c in 'hello'
# Out:
#   Cell In[6], line 1
#     c.upper() for c in 'hello'
#               ^
# SyntaxError: invalid syntax

# %%
# list comprehensions
[c.upper() for c in 'hello']
# Out:
# ['H', 'E', 'L', 'L', 'O']

# %%
demo_list=[]
numbers= [12,35,64,76,89]
for num in numbers:
    demo_list.append(num*2)

# %%
demo_list
# Out:
# [24, 70, 128, 152, 178]

# %%
[num*2 for num in numbers]
# Out:
# [24, 70, 128, 152, 178]

# %%
[x**2 for x in range(11,45,3)]
# Out:
# [121, 196, 289, 400, 529, 676, 841, 1024, 1225, 1444, 1681, 1936]

# %%
num_list= [1,2,3,4,5,6,7,8]
[f'{num} is even' for num in num_list if num%2==0]
# Out:
# ['2 is even', '4 is even', '6 is even', '8 is even']

# %%
[x**2 for x in range(11,45,3)]
# Out:
# [121, 196, 289, 400, 529, 676, 841, 1024, 1225, 1444, 1681, 1936]

# %%
[num/2 for num in [x**2 for x in range(11,45,3)]]
# Out:
# [60.5,
#  98.0,
#  144.5,
#  200.0,
#  264.5,
#  338.0,
#  420.5,
#  512.0,
#  612.5,
#  722.0,
#  840.5,
#  968.0]

# %%
num_list= [1,2,3,4,5,6,7,8]
[f'{num} is even' if num%2==0 else f'{num} is odd' for num in num_list]
# Out:
# ['1 is odd',
#  '2 is even',
#  '3 is odd',
#  '4 is even',
#  '5 is odd',
#  '6 is even',
#  '7 is odd',
#  '8 is even']

# %% [markdown]
# 1. Create a strings "This is a course on Machine Learning which is a foundational branch of Artificial Intelligence domain"
# 2. Put first letter of every word of s in a list and capitalize it
# 3. Filter out all the vowels from the string and store remaining characters in a list
# 4. Get me the length of all the words in s
# 5. Tell me whether each of the word is divisible by 3 or not

# %%
s= "This is a course on Machine Learning which is a foundational branch of Artificial Intelligence domain"

# %%
s
# Out:
# 'This is a course on Machine Learning which is a foundational branch of Artificial Intelligence domain'

# %%
s.split()
# Out:
# ['This',
#  'is',
#  'a',
#  'course',
#  'on',
#  'Machine',
#  'Learning',
#  'which',
#  'is',
#  'a',
#  'foundational',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence',
#  'domain']

# %%
#2
[w for w in s]
# Out:
# ['T',
#  'h',
#  'i',
#  's',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'c',
#  'o',
#  'u',
#  'r',
#  's',
#  'e',
#  ' ',
#  'o',
#  'n',
#  ' ',
#  'M',
#  'a',
#  'c',
#  'h',
#  'i',
#  'n',
#  'e',
#  ' ',
#  'L',
#  'e',
#  'a',
#  'r',
#  'n',
#  'i',
#  'n',
#  'g',
#  ' ',
#  'w',
#  'h',
#  'i',
#  'c',
#  'h',
#  ' ',
#  'i',
#  's',
#  ' ',
#  'a',
#  ' ',
#  'f',
#  'o',
#  'u',
#  'n',
#  'd',
#  'a',
#  't',
#  'i',
#  'o',
#  'n',
#  'a',
#  'l',
#  ' ',
#  'b',
#  'r',
#  'a',
#  'n',
#  'c',
#  'h',
#  ' ',
#  'o',
#  'f',
#  ' ',
#  'A',
#  'r',
#  't',
#  'i',
#  'f',
#  'i',
#  'c',
#  'i',
#  'a',
#  'l',
#  ' ',
#  'I',
#  'n',
#  't',
#  'e',
#  'l',
#  'l',
#  'i',
#  'g',
#  'e',
#  'n',
#  'c',
#  'e',
#  ' ',
#  'd',
#  'o',
#  'm',
#  'a',
#  'i',
#  'n']

# %%
[w for w in s.split()]
# Out:
# ['This',
#  'is',
#  'a',
#  'course',
#  'on',
#  'Machine',
#  'Learning',
#  'which',
#  'is',
#  'a',
#  'foundational',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence',
#  'domain']

# %%
[w[0] for w in s.split()]
# Out:
# ['T',
#  'i',
#  'a',
#  'c',
#  'o',
#  'M',
#  'L',
#  'w',
#  'i',
#  'a',
#  'f',
#  'b',
#  'o',
#  'A',
#  'I',
#  'd']

# %%
[w[0].upper() for w in s.split()]
# Out:
# ['T',
#  'I',
#  'A',
#  'C',
#  'O',
#  'M',
#  'L',
#  'W',
#  'I',
#  'A',
#  'F',
#  'B',
#  'O',
#  'A',
#  'I',
#  'D']

# %%
demo_list=[]
for w in s.split():
    demo_list.append(w)
demo_list
# Out:
# ['This',
#  'is',
#  'a',
#  'course',
#  'on',
#  'Machine',
#  'Learning',
#  'which',
#  'is',
#  'a',
#  'foundational',
#  'branch',
#  'of',
#  'Artificial',
#  'Intelligence',
#  'domain']

# %%
demo_list=[]
for w in s.split():
    demo_list.append(w[0])
demo_list
# Out:
# ['T',
#  'i',
#  'a',
#  'c',
#  'o',
#  'M',
#  'L',
#  'w',
#  'i',
#  'a',
#  'f',
#  'b',
#  'o',
#  'A',
#  'I',
#  'd']

# %%
demo_list=[]
for w in s.split():
    demo_list.append(w[0].upper())
demo_list
# Out:
# ['T',
#  'I',
#  'A',
#  'C',
#  'O',
#  'M',
#  'L',
#  'W',
#  'I',
#  'A',
#  'F',
#  'B',
#  'O',
#  'A',
#  'I',
#  'D']

# %%
[c for c in s if c not in 'aeiouAEIOU']
# Out:
# ['T',
#  'h',
#  's',
#  ' ',
#  's',
#  ' ',
#  ' ',
#  'c',
#  'r',
#  's',
#  ' ',
#  'n',
#  ' ',
#  'M',
#  'c',
#  'h',
#  'n',
#  ' ',
#  'L',
#  'r',
#  'n',
#  'n',
#  'g',
#  ' ',
#  'w',
#  'h',
#  'c',
#  'h',
#  ' ',
#  's',
#  ' ',
#  ' ',
#  'f',
#  'n',
#  'd',
#  't',
#  'n',
#  'l',
#  ' ',
#  'b',
#  'r',
#  'n',
#  'c',
#  'h',
#  ' ',
#  'f',
#  ' ',
#  'r',
#  't',
#  'f',
#  'c',
#  'l',
#  ' ',
#  'n',
#  't',
#  'l',
#  'l',
#  'g',
#  'n',
#  'c',
#  ' ',
#  'd',
#  'm',
#  'n']

# %%
[f"the length of word '{w}' is {len(w)}" for w in s.split()]
# Out:
# ["the length of word 'This' is 4",
#  "the length of word 'is' is 2",
#  "the length of word 'a' is 1",
#  "the length of word 'course' is 6",
#  "the length of word 'on' is 2",
#  "the length of word 'Machine' is 7",
#  "the length of word 'Learning' is 8",
#  "the length of word 'which' is 5",
#  "the length of word 'is' is 2",
#  "the length of word 'a' is 1",
#  "the length of word 'foundational' is 12",
#  "the length of word 'branch' is 6",
#  "the length of word 'of' is 2",
#  "the length of word 'Artificial' is 10",
#  "the length of word 'Intelligence' is 12",
#  "the length of word 'domain' is 6"]

# %%
[f"the word {w} is divisible by 3" if len(w)%3==0 else f"the word {w} is not divisible by 3" for w in s.split()]
# Out:
# ['the word This is not divisible by 3',
#  'the word is is not divisible by 3',
#  'the word a is not divisible by 3',
#  'the word course is divisible by 3',
#  'the word on is not divisible by 3',
#  'the word Machine is not divisible by 3',
#  'the word Learning is not divisible by 3',
#  'the word which is not divisible by 3',
#  'the word is is not divisible by 3',
#  'the word a is not divisible by 3',
#  'the word foundational is divisible by 3',
#  'the word branch is divisible by 3',
#  'the word of is not divisible by 3',
#  'the word Artificial is not divisible by 3',
#  'the word Intelligence is divisible by 3',
#  'the word domain is divisible by 3']

# %%
[f"the length of word {w} is {len(w)} which is divisible by 3" for w in s.split() if len(w)%3==0]
# Out:
# ['the length of word course is 6 which is divisible by 3',
#  'the length of word foundational is 12 which is divisible by 3',
#  'the length of word branch is 6 which is divisible by 3',
#  'the length of word Intelligence is 12 which is divisible by 3',
#  'the length of word domain is 6 which is divisible by 3']
