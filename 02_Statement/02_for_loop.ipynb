# %%
num_list= [1,2,3,4,5,6,7,8]

# %%
num_list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
for num in num_list:
    print(num+50)
# Out:
# 51
# 52
# 53
# 54
# 55
# 56
# 57
# 58

# %%
for num in num_list:
    print(50)
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
for num in num_list:
    if num%2==0:
        print(num)
# Out:
# 2
# 4
# 6
# 8

# %%
for num in num_list:
    if num%2==0:
        print(num)
    else:
        print(f"the number '{num}' is odd number")
# Out:
# the number '1' is odd number
# 2
# the number '3' is odd number
# 4
# the number '5' is odd number
# 6
# the number '7' is odd number
# 8

# %%
list_sum=0
for num in num_list:
    list_sum+= num
print(list_sum)
# Out:
# 36

# %%
for c in 'this is a string':
    print(c)
# Out:
# t
# h
# i
# s
#
# i
# s
#
# a
#
# s
# t
# r
# i
# n
# g

# %%
'this is a string'.split()
# Out:
# ['this', 'is', 'a', 'string']

# %%
for word in 'this is a string'.split():
    print(word)
# Out:
# this
# is
# a
# string

# %%
t=(1,2,3,4,5,6,7,8)
for num in t:
    print(num+20)
# Out:
# 21
# 22
# 23
# 24
# 25
# 26
# 27
# 28

# %%
list2= [(1,2),(3,4),(5,6),(7,8)]

# %%
for item in list2:
    print(item)
# Out:
# (1, 2)
# (3, 4)
# (5, 6)
# (7, 8)

# %%
for t1,t2 in list2:
    print(t1)
    print(t2)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
demo_dict= {'k1':12,
            'k2':'hello',
            'k3':[34,21]}

# %%
demo_dict.items()
# Out:
# dict_items([('k1', 12), ('k2', 'hello'), ('k3', [34, 21])])

# %%
for k,v in demo_dict.items():
    print(f" for the key '{k}', the value is '{v}'")
# Out:
#  for the key 'k1', the value is '12'
#  for the key 'k2', the value is 'hello'
#  for the key 'k3', the value is '[34, 21]'
