# %%
if 7>4:
    print('hello')
# Out:
# hello

# %%
if True:
    print('it was true')
# Out:
# it was true

# %%
x= False
if x:
    print('x here was True')
else:
    print('I got printed because x is not True')
# Out:
# I got printed because x is not True

# %%
y= 4>5

# %%
y
# Out:
# False

# %% [markdown]
# ### Multiple Branches

# %%
loc= input('enter your location here:')
# Out:
# enter your location here: delhi

# %%
loc
# Out:
# 'delhi'

# %%
loc= input('enter your location here:')
loc= loc.lower()
if loc=='delhi':
    print('1')
elif loc=='mumbai':
    print('2')
elif loc=='chennai':
    print('3')
else:
    print('where are you')
# Out:
# enter your location here: Delhi
# 1
