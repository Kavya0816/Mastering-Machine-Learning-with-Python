# %%
x= 10/4

# %%
x
# Out:
# 2.5

# %%
x=7/3

# %%
x
# Out:
# 2.3333333333333335

# %%
type(x)
# Out:
# float

# %%
myincome= 1000
anualincome= myincome*12
taxrate=10
taxamount=(taxrate/100)*anualincome

# %%
taxamount
# Out:
# 1200.0
