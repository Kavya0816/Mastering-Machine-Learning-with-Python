# %%
x= set()

# %%
x
# Out:
# set()

# %%
type(x)
# Out:
# set

# %%
x.add(11)

# %%
x
# Out:
# {11}

# %%
x.add(2)

# %%
x
# Out:
# {2, 11}

# %%
x.add('hi')

# %%
x
# Out:
# {11, 2, 'hi'}

# %%
x.add('hi')

# %%
x
# Out:
# {11, 2, 'hi'}

# %%
x.add('Hi')

# %%
x
# Out:
# {11, 2, 'Hi', 'hi'}

# %%
'hi'=='Hi'
# Out:
# False

# %%
l1=[1,4,3,6,8,6,3,6,9,4345,7,9,54,4,6,8,76,53,3,5,6]

# %%
# cast as set to get unique values
set(l1)
# Out:
# {1, 3, 4, 5, 6, 7, 8, 9, 53, 54, 76, 4345}

# %% [markdown]
# ### Booleans

# %%
# equal
3 == 2
# Out:
# False

# %%
# not equal
3 != 2
# Out:
# True

# %%
3>2
# Out:
# True

# %%
3<2
# Out:
# False

# %%
3>=2
# Out:
# True

# %%
3>3
# Out:
# False

# %%
3>=3
# Out:
# True

# %% [markdown]
# ### Chained Comparison Operators

# %%
2<3<5
# Out:
# True

# %%
2<3 and 3<5
# Out:
# True

# %%
2<3 and 3>5
# Out:
# False
