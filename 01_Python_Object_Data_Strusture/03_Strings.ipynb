# %% [markdown]
# ### creating a string

# %%
'hello'
# Out:
# 'hello'

# %%
"hello"
# Out:
# 'hello'

# %%
'i'm going'
# Out:
#   Cell In[4], line 1
#     'i'm going'
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"i'm going"
# Out:
# "i'm going"

# %% [markdown]
# ### printing a string

# %%
'hello world 1'
'hello world 2'
# Out:
# 'hello world 2'

# %%
print('hello world 1')
print('hello world 2')
# Out:
# hello world 1
# hello world 2

# %% [markdown]
# ### string basics

# %%
len('i am a student')
# Out:
# 14

# %% [markdown]
# ### string indexing

# %%
s= 'string'

# %%
s
# Out:
# 'string'

# %%
s[0]
# Out:
# 's'

# %%
s[4]
# Out:
# 'n'

# %%
s[-2]
# Out:
# 'n'

# %%
s[-3]
# Out:
# 'i'

# %%
len(s)
# Out:
# 6

# %%
s[1:4]
# Out:
# 'tri'

# %%
s[-6:4]
# Out:
# 'stri'

# %%
s[1:-3]
# Out:
# 'tr'

# %%
s[-3:]
# Out:
# 'ing'

# %%
s[:-2]
# Out:
# 'stri'

# %%
full_name= 'kavya taneja'

# %%
first_name= full_name[:5]

# %%
first_name
# Out:
# 'kavya'

# %%
last_name=full_name[-6:]

# %%
last_name
# Out:
# 'taneja'

# %% [markdown]
# ###### Basic List Methods

# %%
'kavya'+'  '+'taneja' #concatination of strings
# Out:
# 'kavya  taneja'

# %%
s='rahul'

# %%
s[0]
# Out:
# 'r'

# %%
s[0]='p' # strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s[0]='p'
#
# TypeError: 'str' object does not support item assignment

# %%
l1=[11,202,3333]

# %%
l1
# Out:
# [11, 202, 3333]

# %%
l1[2]
# Out:
# 3333

# %%
l1[2]='hello'

# %%
l1 # list are mutable (tuples are immutable)
# Out:
# [11, 202, 'hello']

# %%
'123'*5
# Out:
# '123123123123123'

# %%
s='welcome to india'

# %%
s
# Out:
# 'welcome to india'

# %%
s.upper()
# Out:
# 'WELCOME TO INDIA'

# %% [markdown]
# #### methods are functions inside a class

# %%
# split a string by blank space(by default)
l2= s.split()

# %%
l2
# Out:
# ['welcome', 'to', 'india']

# %%
type(l2)
# Out:
# list

# %%
s.split(o)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 s.split(o)
#
# NameError: name 'o' is not defined

# %%
s.split('o)
# Out:
#   Cell In[25], line 1
#     s.split('o)
#             ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s.split('o')
# Out:
# ['welc', 'me t', ' india']

# %%
s.split('to')
# Out:
# ['welcome ', ' india']

# %%
s.split(' to ')
# Out:
# ['welcome', 'india']

# %%
s.count('o')
# Out:
# 2

# %%
s.find('to') # returns the starting index position of the first appearance
# Out:
# 8

# %%
demo_string='hello'

# %%
demo_string.capitalize()
# Out:
# 'Hello'

# %%
demo_string.isalnum() # if all the characters in this string are either alphabets or numbers
# Out:
# True

# %%
demo_string.islower()
# Out:
# True

# %%
demo_string.isupper()
# Out:
# False

# %%
n='123456'

# %%
n.isnumeric()
# Out:
# True

# %% [markdown]
# ### print formating with strings( formated string literals f-strings)

# %%
name='shreyas'
course='mmlp'
institute='iitr'
partner='rbpl'

# %%
f'this course {course} is led by {name} in association with {institute} and {partner}
# Out:
#   Cell In[40], line 1
#     f'this course {course} is led by {name} in association with {institute} and {partner}
#     ^
# SyntaxError: unterminated f-string literal (detected at line 1)

# %%
f'this course {course} is led by {name} in association with {institute} and {partner}'
# Out:
# 'this course mmlp is led by shreyas in association with iitr and rbpl'

# %%
f'this course {course} is led by {name.upper()} in association with {institute} and {partner}'
# Out:
# 'this course mmlp is led by SHREYAS in association with iitr and rbpl'
