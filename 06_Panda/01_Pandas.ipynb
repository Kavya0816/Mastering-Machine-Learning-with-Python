# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Create a series from Python Objects
#
# ##### Index and Data lists

# %%
myindex=['USA','Canada','India']
mydata=[1776,1867,1947]

# %%
myser= pd.Series(data=my_data)

# %%
myser
# Out:
# 0    1776
# 1    1867
# 2    1947
# dtype: int64

# %%
type(myser)
# Out:
# pandas.core.series.Series

# %%
pd.Series(data=mydata,index=myindex)
# Out:
# USA       1776
# Canada    1867
# India     1947
# dtype: int64

# %%
pd.Series(mydata,myindex)
# Out:
# USA       1776
# Canada    1867
# India     1947
# dtype: int64

# %%
pd.Series(myindex,mydata)
# Out:
# 1776       USA
# 1867    Canada
# 1947     India
# dtype: object

# %%
pd.Series(index=myindex,data=mydata)
# Out:
# USA       1776
# Canada    1867
# India     1947
# dtype: int64

# %%
random_data= np.random.randint(0,100,4)

# %%
random_data
# Out:
# array([26,  9,  1, 50], dtype=int32)

# %%
people=['Andy','Bob','Chetan','David']

# %%
ages= pd.Series(random_data,people)
ages
# Out:
# Andy      26
# Bob        9
# Chetan     1
# David     50
# dtype: int32

# %%
ages={'Xabi':70,
      'Yashika':30,
      'Zack':18}

# %%
pd.Series(ages)
# Out:
# Xabi       70
# Yashika    30
# Zack       18
# dtype: int64

# %% [markdown]
# ### Key Ideas in a Series

# %%
sales_q1= pd.Series({
    'Japan':800,
    'China':4500,
    'India':5000,
    'USA':2500})

sales_q2= pd.Series({
    'Brazil':10000,
    'China':4000,
    'India':2100,
    'USA':2600})

# %%
sales_q1
# Out:
# Japan     800
# China    4500
# India    5000
# USA      2500
# dtype: int64

# %%
sales_q2
# Out:
# Brazil    10000
# China      4000
# India      2100
# USA        2600
# dtype: int64

# %%
# call values based on named index

sales_q1['India']
# Out:
# np.int64(5000)

# %%
sales_q1(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sales_q1(0)
#
# TypeError: 'Series' object is not callable

# %%
sales_q1[0]
# Out:
# C:\Users\Taneja\AppData\Local\Temp\ipykernel_9180\92651501.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales_q1[0]
# np.int64(800)

# %%
sales_q1[2]
# Out:
# C:\Users\Taneja\AppData\Local\Temp\ipykernel_9180\1197006164.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sales_q1[2]
# np.int64(5000)

# %%
sales_q1.iloc[2]
# Out:
# np.int64(5000)

# %% [markdown]
# ### Operations

# %%
sales_q1
# Out:
# Japan     800
# China    4500
# India    5000
# USA      2500
# dtype: int64

# %%
sales_q1.keys()
# Out:
# Index(['Japan', 'China', 'India', 'USA'], dtype='object')

# %%
sales_q1*2
# Out:
# Japan     1600
# China     9000
# India    10000
# USA       5000
# dtype: int64

# %%
sales_q1/3
# Out:
# Japan     266.666667
# China    1500.000000
# India    1666.666667
# USA       833.333333
# dtype: float64

# %%
sales_q1+sales_q2
# Out:
# Brazil       NaN
# China     8500.0
# India     7100.0
# Japan        NaN
# USA       5100.0
# dtype: float64

# %%
sales_q1-sales_q2
# Out:
# Brazil       NaN
# China      500.0
# India     2900.0
# Japan        NaN
# USA       -100.0
# dtype: float64

# %%
sales_q1.add(sales_q2,fill_value=1)
# Out:
# Brazil    10001.0
# China      8500.0
# India      7100.0
# Japan       801.0
# USA        5100.0
# dtype: float64

# %%
sales_q1.subtract(sales_q2,fill_value=1)
# Out:
# Brazil   -9999.0
# China      500.0
# India     2900.0
# Japan      799.0
# USA       -100.0
# dtype: float64
