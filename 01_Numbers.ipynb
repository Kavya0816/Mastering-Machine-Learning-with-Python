# %%
23-9
# Out:
# 14

# %%
3+4
# Out:
# 7

# %%
# heading

# %% [markdown]
# # heading then pressed enter, initially pressed m to markdown this cell
# the more the no. of #, the less the size of text

# %% [markdown]
# # heading

# %% [markdown]
# # heading 1
# ## heading 2
# ### heading 3
# #### heading 4

# %% [markdown]
# #

# %%
7/4
# Out:
# 1.75

# %%
7//4
# Out:
# 1

# %%
7%4
# Out:
# 3
