# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('dm_office_sales.csv')
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(9,3))
sns.countplot(data=df,x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(9,3))
#sns.countplot(data=df,x='level of education',hue='division')
sns.countplot(data=df,x='level of education',hue='division',palette='Blues')
# Out:
# <Axes: xlabel='level of education', ylabel='count'>

# %%
df['level of education'].value_counts()
# Out:
# level of education
# associate's degree    412
# some college          392
# high school           108
# bachelor's degree      85
# master's degree         3
# Name: count, dtype: int64

# %% [markdown]
# ### Barplot

# %%
# Note: the height of each column represent the mean value or variance or sum and the vertical line above represent the standard deviation
plt.figure(figsize=(12,3))
#sns.barplot(x='level of education',y='salary',data=df, estimator=np.mean)
#sns.barplot(x='level of education',y='salary',data=df, estimator=np.mean,hue='division')
#sns.barplot(x='level of education',y='salary',data=df, estimator=np.var,hue='division')
sns.barplot(x='level of education',y='salary',data=df, estimator=np.sum,hue='division')
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>
